# %% [markdown]
# # 🐍 Python Basics – Lab 01
# Complete beginner notes with examples

# %% [markdown]
# ## 1. What is Python?
# Python is a high-level, interpreted programming language used for web, data science, AI, and automation.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## 2. Variables and Data Types

# %%
age = 40.1

# %%
print (age)
# Out:
# 40

# %%
print("I am", age, "year old")
# Out:
# I am 40 year old

# %%
name = "asad raza"

# %%
print("My name is", name)
# Out:
# My name is asad

# %%
is_student = True

# %%
print("am i student", is_student)
# Out:
# am i student True

# %%
x = 10
y = 3.5
name = "Asad"
is_student = True
print(x, y, name, is_student)
# Out:
# 10 3.5 Asad True

# %% [markdown]
# ## 3. Operators

# %%
print(5 + 2)
print(5 * 2)
print(5 > 2)

# %% [markdown]
# ## 4. If-Else

# %%
age = 18
if age >= 18:
    print("Eligible")
else:
    print("Not eligible")

# %% [markdown]
# ## 5. Summary
# Practice is key to learning Python.
